# %%
import pandas as pd
import numpy as np
import seaborn as se
import matplotlib.pyplot as plt

# %%
sp=pd.read_csv("C:\DSBDA\weatherAUS.csv")

# %%
sp.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
sp.head(6)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
# ...

# %%
sp.tail(3)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 142190       NaN         NNW           22.0         SE  ...        21.0
# 142191       NaN           N           37.0         SE  ...        24.0
# 142192       NaN          SE           28.0        SSE  ...        24.0
#
#         Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 142190       1023.5       1019.1       NaN       NaN     10.9     24.5
# 142191       1021.0       1016.8       NaN       NaN     12.5     26.1
# 142192       1019.4       1016.5       3.0       2.0     15.1     26.0
#
#         RainToday  RISK_MM  RainTomorrow
# 142190         No      0.0            No
# ...

# %%
sp.index
# Out:
# RangeIndex(start=0, stop=142193, step=1)

# %%
sp.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
sp.shape
# Out:
# (142193, 24)

# %%
sp.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
sp.columns.values
# Out:
# array(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall',
#        'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed',
#        'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm',
#        'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm',
#        'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'RainToday',
#        'RISK_MM', 'RainTomorrow'], dtype=object)

# %%
sp.describe(include="all")
# Out:
#               Date  Location        MinTemp        MaxTemp       Rainfall  \
# count       142193    142193  141556.000000  141871.000000  140787.000000
# unique        3436        49            NaN            NaN            NaN
# top     2013-12-01  Canberra            NaN            NaN            NaN
# freq            49      3418            NaN            NaN            NaN
# mean           NaN       NaN      12.186400      23.226784       2.349974
# std            NaN       NaN       6.403283       7.117618       8.465173
# min            NaN       NaN      -8.500000      -4.800000       0.000000
# 25%            NaN       NaN       7.600000      17.900000       0.000000
# 50%            NaN       NaN      12.000000      22.600000       0.000000
# 75%            NaN       NaN      16.800000      28.200000       0.800000
# max            NaN       NaN      33.900000      48.100000     371.000000
#
#          Evaporation      Sunshine WindGustDir  WindGustSpeed WindDir9am  ...  \
# ...

# %%
sp['Location']
# Out:
# 0         Albury
# 1         Albury
# 2         Albury
# 3         Albury
# 4         Albury
#            ...
# 142188     Uluru
# 142189     Uluru
# 142190     Uluru
# 142191     Uluru
# 142192     Uluru
# Name: Location, Length: 142193, dtype: object

# %%
sp.sort_index(axis=1,ascending=False)
# Out:
#         WindSpeed9am  WindSpeed3pm  WindGustSpeed WindGustDir WindDir9am  \
# 0               20.0          24.0           44.0           W          W
# 1                4.0          22.0           44.0         WNW        NNW
# 2               19.0          26.0           46.0         WSW          W
# 3               11.0           9.0           24.0          NE         SE
# 4                7.0          20.0           41.0           W        ENE
# ...              ...           ...            ...         ...        ...
# 142188          15.0          13.0           31.0           E        ESE
# 142189          13.0          11.0           31.0           E         SE
# 142190          13.0           9.0           22.0         NNW         SE
# 142191           9.0           9.0           37.0           N         SE
# 142192          13.0           7.0           28.0          SE        SSE
#
#        WindDir3pm  Temp9am  Temp3pm  Sunshine  Rainfall  ... Pressure3pm  \
# ...

# %%
sp.sort_values(by="Location")
# Out:
#               Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 94847   2011-05-16  Adelaide      5.2     16.6       0.0          3.6
# 95911   2014-08-14  Adelaide      9.8     15.5       0.0          2.2
# 95912   2014-08-15  Adelaide      8.5     20.3       0.0          2.0
# 95913   2014-08-16  Adelaide     10.3     14.0       0.0          NaN
# 95914   2014-08-17  Adelaide      9.4     16.2       1.8          NaN
# ...            ...       ...      ...      ...       ...          ...
# 104165  2012-05-09   Woomera     13.1     25.3       0.0         15.4
# 104166  2012-05-10   Woomera     13.4     25.1       0.2          7.0
# 104167  2012-05-11   Woomera     10.8     22.3       0.0          5.8
# 104159  2012-05-03   Woomera      7.1     17.7       0.0          6.2
# 105809  2017-01-17   Woomera     22.7     43.5       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# ...

# %%
sp.iloc[5]
# Out:
# Date             2008-12-06
# Location             Albury
# MinTemp                14.6
# MaxTemp                29.7
# Rainfall                0.2
# Evaporation             NaN
# Sunshine                NaN
# WindGustDir             WNW
# WindGustSpeed          56.0
# WindDir9am                W
# WindDir3pm                W
# WindSpeed9am           19.0
# WindSpeed3pm           24.0
# Humidity9am            55.0
# Humidity3pm            23.0
# Pressure9am          1009.2
# Pressure3pm          1005.4
# Cloud9am                NaN
# Cloud3pm                NaN
# Temp9am                20.6
# Temp3pm                28.9
# RainToday                No
# RISK_MM                 0.0
# RainTomorrow             No
# Name: 5, dtype: object

# %%
sp[0:3]
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1007.1       8.0       NaN     16.9     21.8         No      0.0
# 1       1007.8       NaN       NaN     17.2     24.3         No      0.0
# 2       1008.7       NaN       2.0     21.0     23.2         No      0.0
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
#
# ...

# %%
sp.loc[:,["Date","Location"]]
# Out:
#               Date Location
# 0       2008-12-01   Albury
# 1       2008-12-02   Albury
# 2       2008-12-03   Albury
# 3       2008-12-04   Albury
# 4       2008-12-05   Albury
# ...            ...      ...
# 142188  2017-06-20    Uluru
# 142189  2017-06-21    Uluru
# 142190  2017-06-22    Uluru
# 142191  2017-06-23    Uluru
# 142192  2017-06-24    Uluru
#
# [142193 rows x 2 columns]

# %%
sp.iloc[:12,:]
# Out:
#           Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1   2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2   2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3   2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4   2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5   2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6   2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7   2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8   2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9   2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
# 10  2008-12-11   Albury     13.4     30.4       0.0          NaN       NaN
# ...

# %%
sp.iloc[:,:12]
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am WindDir3pm  \
# 0            NaN           W           44.0          W        WNW
# ...

# %%
sp.iloc[:12,:12]
# Out:
#           Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1   2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2   2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3   2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4   2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5   2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6   2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7   2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8   2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9   2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
# 10  2008-12-11   Albury     13.4     30.4       0.0          NaN       NaN
# ...

# %%
sp.iloc[3:5,0:2]
# Out:
#          Date Location
# 3  2008-12-04   Albury
# 4  2008-12-05   Albury

# %%
sp.iloc[[1,2,4],[0,2]]
# Out:
#          Date  MinTemp
# 1  2008-12-02      7.4
# 2  2008-12-03     12.9
# 4  2008-12-05     17.5

# %%
sp.iloc[:,1:3]
# Out:
#        Location  MinTemp
# 0        Albury     13.4
# 1        Albury      7.4
# 2        Albury     12.9
# 3        Albury      9.2
# 4        Albury     17.5
# ...         ...      ...
# 142188    Uluru      3.5
# 142189    Uluru      2.8
# 142190    Uluru      3.6
# 142191    Uluru      5.4
# 142192    Uluru      7.8
#
# [142193 rows x 2 columns]

# %%
sp.iloc[1,1]
# Out:
# 'Albury'

# %%
import pandas as pd
from sklearn import preprocessing

# %%
sp=pd.read_csv("C:\DSBDA\weatherAUS.csv")

# %%
sp.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
sp['Date'] = pd.to_datetime(sp['Date'], format='%Y-%m-%d')

# %%
sp.dtypes
# Out:
# Date             datetime64[ns]
# Location                 object
# MinTemp                 float64
# MaxTemp                 float64
# Rainfall                float64
# Evaporation             float64
# Sunshine                float64
# WindGustDir              object
# WindGustSpeed           float64
# WindDir9am               object
# WindDir3pm               object
# WindSpeed9am            float64
# WindSpeed3pm            float64
# Humidity9am             float64
# Humidity3pm             float64
# Pressure9am             float64
# Pressure3pm             float64
# Cloud9am                float64
# Cloud3pm                float64
# Temp9am                 float64
# Temp3pm                 float64
# RainToday                object
# RISK_MM                 float64
# RainTomorrow             object
# dtype: object

# %%
sp["RainToday"]=sp["RainToday"].astype("string")

# %%
sp.dtypes
# Out:
# Date             datetime64[ns]
# Location                 object
# MinTemp                 float64
# MaxTemp                 float64
# Rainfall                float64
# Evaporation             float64
# Sunshine                float64
# WindGustDir              object
# WindGustSpeed           float64
# WindDir9am               object
# WindDir3pm               object
# WindSpeed9am            float64
# WindSpeed3pm            float64
# Humidity9am             float64
# Humidity3pm             float64
# Pressure9am             float64
# Pressure3pm             float64
# Cloud9am                float64
# Cloud3pm                float64
# Temp9am                 float64
# Temp3pm                 float64
# RainToday        string[python]
# RISK_MM                 float64
# RainTomorrow             object
# dtype: object

# %%
sp['Location'].unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
sp['Location']= label_encoder.fit_transform(sp['Location'])

# %%
sp['Location'].unique()
# Out:
# array([ 2,  4, 10, 11, 21, 24, 26, 27, 30, 34, 37, 38, 42, 45, 47,  9, 40,
#        23,  5,  6, 35, 19, 18, 20, 25, 33, 44, 12,  7,  8, 14, 39,  0, 22,
#        28, 48,  1, 46, 29, 32, 31, 36, 43, 15, 17,  3, 13, 16, 41])
