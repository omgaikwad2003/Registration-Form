# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\DSBDA\StudentsPerformance.csv")

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female            NaN             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4       NaN        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False            True                        False  False
# 3     False           False                        False  False
# 4      True           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
series = pd.isnull(df["math score"]) 
df[series]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 2  female            NaN             master's degree  standard
# 5  female        group B          associate's degree  standard
#
#   test preparation course  math score  reading score  writing score
# 2                    none         NaN           95.0           93.0
# 5                    none         NaN            NaN           78.0

# %%
df.notnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0      True            True                         True   True
# 1      True            True                         True   True
# 2      True           False                         True   True
# 3      True            True                         True   True
# 4     False            True                         True   True
# ..      ...             ...                          ...    ...
# 995    True            True                         True   True
# 996    True            True                         True   True
# 997    True            True                         True   True
# 998    True            True                         True   True
# 999    True            True                         True   True
#
#      test preparation course  math score  reading score  writing score
# 0                       True        True           True           True
# ...

# %%
series1 = pd.notnull(df["math score"]) 
df[series1]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 3      male        group A          associate's degree  free/reduced
# 4       NaN        group C                some college      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.isnull().any()
# Out:
# gender                          True
# race/ethnicity                  True
# parental level of education    False
# lunch                           True
# test preparation course        False
# math score                      True
# reading score                   True
# writing score                   True
# dtype: bool

# %%
df.isnull().sum().sum()
# Out:
# 9

# %%
df.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      2
# 3      0
# 4      1
#       ..
# 995    0
# 996    0
# 997    0
# 998    0
# 999    0
# Length: 1000, dtype: int64

# %%
df.isnull().sum()
# Out:
# gender                         1
# race/ethnicity                 2
# parental level of education    0
# lunch                          1
# test preparation course        0
# math score                     2
# reading score                  1
# writing score                  2
# dtype: int64

# %%
df.isna().sum()
# Out:
# gender                         1
# race/ethnicity                 2
# parental level of education    0
# lunch                          1
# test preparation course        0
# math score                     2
# reading score                  1
# writing score                  2
# dtype: int64

# %%
df.gender.isnull().sum()
# Out:
# 1

# %%
df['math score'] = df['math score'].fillna(df['math score'].max())
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female            NaN             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4       NaN        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
missing_values = ["NaN", "na"]

# %%
df = pd.read_csv("C:\DSBDA\StudentsPerformance.csv", na_values = missing_values) 
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female            NaN             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4       NaN        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
ndf=df 
ndf.fillna(0)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female              0             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4         0        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['math score'] = df['math score'].fillna(df['math score'].mean()) 
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female            NaN             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4       NaN        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
print(df)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female            NaN             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4       NaN        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['reading score'] = df['reading score'].fillna(df['reading score'].median()) 
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female            NaN             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4       NaN        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
m_v=df['math score'].mean() 
df['math score'].fillna(value=m_v, inplace=True) 
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female            NaN             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4       NaN        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
ndf.replace(to_replace = np.nan, value = -99)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female            -99             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4       -99        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
ndf1=df

# %%
ndf1.dropna()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 3      male        group A          associate's degree  free/reduced
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
ndf1.dropna(how="all")
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female            NaN             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4       NaN        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
ndf1.dropna(axis=1)
# Out:
#     parental level of education test preparation course  math score  \
# 0             bachelor's degree                    none    72.00000
# 1                  some college               completed    69.00000
# 2               master's degree                    none    66.06012
# 3            associate's degree                    none    47.00000
# 4                  some college                    none    76.00000
# ..                          ...                     ...         ...
# 995             master's degree               completed    88.00000
# 996                 high school                    none    62.00000
# 997                 high school               completed    59.00000
# 998                some college               completed    68.00000
# 999                some college                    none    77.00000
#
#      reading score
# 0             72.0
# 1             90.0
# 2             95.0
# 3             57.0
# 4             78.0
# ..             ...
# ...

# %%
new_data = df.dropna(axis = 0, how ='any')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
df=pd.read_csv("C:\DSBDA\StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female            NaN             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4       NaN        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
col = ['math score', 'reading score' , 'writing score'] 
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['math score']>90))
# Out:
# (array([ 34, 104, 114, 121, 149, 165, 171, 179, 233, 263, 286, 306, 451,
#        458, 469, 501, 503, 521, 539, 546, 562, 566, 571, 594, 612, 618,
#        623, 625, 685, 689, 710, 712, 717, 719, 736, 779, 784, 815, 846,
#        855, 864, 886, 903, 916, 919, 934, 950, 957, 962, 979], dtype=int64),)

# %%
print(np.where(df['reading score']<25))
# Out:
# (array([ 59, 327, 596, 980], dtype=int64),)

# %%
print(np.where(df['writing score']<30))
# Out:
# (array([ 17,  59,  76, 211, 327, 338, 596, 896, 980], dtype=int64),)

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['math score'], df['reading score'])
plt.show()

# %%
print(np.where((df['math score']<50) & (df['writing score']>1)))
print(np.where((df['writing score']<3 & (df['math score']>85) )))
# Out:
# (array([  3,   7,  11,  17,  18,  22,  33,  55,  59,  61,  66,  69,  72,
#         74,  75,  76,  80,  81,  84,  91,  93, 142, 145, 162, 174, 176,
#        181, 184, 188, 198, 211, 212, 217, 225, 231, 250, 262, 272, 281,
#        284, 296, 298, 309, 323, 324, 327, 329, 331, 337, 338, 339, 353,
#        357, 363, 365, 368, 371, 375, 383, 384, 395, 402, 422, 424, 433,
#        448, 455, 466, 484, 504, 527, 528, 531, 552, 555, 564, 565, 575,
#        578, 587, 589, 596, 601, 607, 616, 620, 628, 629, 640, 658, 683,
#        690, 694, 706, 709, 724, 741, 761, 775, 777, 780, 785, 787, 790,
#        794, 807, 811, 816, 822, 824, 840, 842, 844, 862, 869, 874, 889,
#        895, 896, 902, 913, 914, 917, 921, 928, 929, 947, 948, 958, 961,
#        973, 980, 986, 988], dtype=int64),)
# (array([], dtype=int64),)

# %%
 col = ['reading score']
df.boxplot(col)
plt.show()

# %%
new_df=df 
for i in sample_outliers: 
 new_df.drop(i,inplace=True) 
new_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 new_df=df
# ----> 2 for i in sample_outliers:
#       3  new_df.drop(i,inplace=True)
#       4 new_df
#
# NameError: name 'sample_outliers' is not defined

# %%
new_df =df
new_df['reading score'].plot(kind = 'hist') 
plt.show()

# %%
df['log_math'] = np.log10(df['reading score'])
df['log_math'].plot(kind = 'hist') 
plt.show()
