# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as se

# %%
data=pd.read_csv("titanic.csv")

# %%
from seaborn import load_dataset

# %%
tips=load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
se.countplot(x='Survived',data=data)
plt.show()

# %%
data["Sex"].value_counts().plot(kind='pie',autopct='%.2f')
plt.show()

# %%
plt.hist(data['Age'],bins=5)
plt.show()

# %%
se.distplot(data['Age'])
plt.show()
# Out:
# D:\Jupyter\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.scatter(tips['total_bill'],tips['tip'])
plt.show()

# %%
se.scatterplot(data=tips,x='total_bill',y='tip',hue=tips['sex'])
plt.show()

# %%
se.scatterplot(data=tips,x='total_bill',y='tip',hue=tips['sex'],style=tips['smoker'])
plt.show()

# %%
se.barplot(x='Pclass',y='Age',data=data)
plt.show()

# %%
se.barplot(x='Pclass',y='Age',hue='Sex',data=data)
plt.show()

# %%
se.boxplot(x='Pclass',y='Age',data=data)
plt.show()

# %%
se.boxplot(x='Pclass',y='Age',hue=data['Sex'],data=data)
plt.show()

# %%
pd.crosstab(data['Pclass'],data['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
se.heatmap(pd.crosstab(data['Pclass'],data['Survived']))
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Pclass'>

# %%
se.clustermap(pd.crosstab(data['Pclass'],data['Survived']))
